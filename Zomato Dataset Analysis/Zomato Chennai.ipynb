# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_df = pd.read_csv('Zomato_Chennai.csv')

# %%
raw_df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zomato URL             12032 non-null  object
#  1   Name of Restaurant     12032 non-null  object
#  2   Address                12032 non-null  object
#  3   Location               12032 non-null  object
#  4   Cuisine                12032 non-null  object
#  5   Top Dishes             12032 non-null  object
#  6   Price for 2            12032 non-null  float64
#  7   Dining Rating          6681 non-null   float64
#  8   Dining Rating Count    11812 non-null  object
#  9   Delivery Rating        6181 non-null   float64
#  10  Delivery Rating Count  11812 non-null  object
#  11  Features               12032 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.1+ MB

# %%
raw_df.describe()
# Out:
#         Price for 2  Dining Rating  Delivery Rating
# count  12032.000000    6681.000000      6181.000000
# mean     397.611370       3.387756         3.805290
# std      332.045938       0.558181         0.374213
# min       40.000000       0.300000         0.300000
# 25%      200.000000       3.100000         3.600000
# 50%      300.000000       3.500000         3.900000
# 75%      450.000000       3.800000         4.000000
# max     5000.000000       4.900000         4.700000

# %%
raw_df.drop(['Zomato URL', 'Address'], axis = 1, inplace=True)

# %%
raw_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                  ['Zinger Burger']        500.0
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
#
# ...

# %%
raw_df.isnull().sum()
# Out:
# Name of Restaurant          0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            5351
# Dining Rating Count       220
# Delivery Rating          5851
# Delivery Rating Count     220
# Features                    0
# dtype: int64

# %%
raw_df['Delivery Rating'].fillna(0,inplace=True)
# Out:
# C:\Users\babuk\AppData\Local\Temp\ipykernel_26720\586252972.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   raw_df['Delivery Rating'].fillna(0,inplace=True)

# %%
raw_df['Dining Rating'].fillna(0,inplace=True)

# %%
raw_df.fillna(0,inplace=True)

# %%
raw_df['Delivery Rating Count'].value_counts()
# Out:
# Delivery Rating Count
# Not enough Delivery Reviews    3379
# Does not offer Delivery        2252
# 0                               220
# 27                               34
# 37                               30
#                                ...
# 3530                              1
# 7705                              1
# 6374                              1
# 1773                              1
# 1617                              1
# Name: count, Length: 2282, dtype: int64

# %%
raw_df['Dining Rating Count'].replace('Does not offer Dining',0,inplace=True)
# Out:
# C:\Users\babuk\AppData\Local\Temp\ipykernel_26720\1652975327.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   raw_df['Dining Rating Count'].replace('Does not offer Dining',0,inplace=True)

# %%
raw_df['Delivery Rating Count'].replace('Not enough Delivery Reviews',0,inplace=True)

raw_df['Delivery Rating Count'].replace('Does not offer Delivery',0,inplace=True)
# Out:
# C:\Users\babuk\AppData\Local\Temp\ipykernel_26720\3391431854.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   raw_df['Delivery Rating Count'].replace('Not enough Delivery Reviews',0,inplace=True)
# C:\Users\babuk\AppData\Local\Temp\ipykernel_26720\3391431854.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
raw_df.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
raw_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...        500.0
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...       1000.0
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...        500.0
# 3                                  ['Zinger Burger']        500.0
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...        450.0
#
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     12032 non-null  object
#  1   Location               12032 non-null  object
#  2   Cuisine                12032 non-null  object
#  3   Top Dishes             12032 non-null  object
#  4   Price for 2            12032 non-null  float64
#  5   Dining Rating          12032 non-null  float64
#  6   Dining Rating Count    12032 non-null  object
#  7   Delivery Rating        12032 non-null  float64
#  8   Delivery Rating Count  12032 non-null  object
#  9   Features               12032 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 940.1+ KB

# %%
raw_df['Dining Rating Count'] = raw_df['Dining Rating Count'].astype('int64')
raw_df['Price for 2'] = raw_df['Price for 2'].astype('int64')
raw_df['Delivery Rating Count'] = raw_df['Delivery Rating Count'].astype('int64')

# %%
raw_df['Cuisine'] = raw_df['Cuisine'].str.replace('[', '', regex=False).str.replace(']', '', regex=False)
raw_df['Top Dishes'] = raw_df['Top Dishes'].str.replace('[', '', regex=False).str.replace(']', '', regex=False)
raw_df['Features'] = raw_df['Features'].str.replace('[', '', regex=False).str.replace(']', '', regex=False)

# %%
raw_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                          'Biryani'
# 1  'Biryani', ' North Indian', ' Mughlai', ' Dess...
# 2  'Biryani', ' North Indian', ' Chinese', ' Arab...
# 3  'Burger', ' Fast Food', ' Finger Food', ' Beve...
# 4  'Chinese', ' Biryani', ' North Indian', ' Chet...
#
#                                           Top Dishes  Price for 2  \
# 0  'Bread Halwa', ' Chicken 65', ' Mutton Biryani...          500
# 1  'Beef Biryani', ' Beef Fry', ' Paratha', ' Pay...         1000
# 2  'Brinjal Curry', ' Tandoori Chicken', ' Chicke...          500
# 3                                    'Zinger Burger'          500
# 4  'Mutton Biryani', ' Chicken Rice', ' Tomato Ri...          450
#
# ...

# %%
raw_df['Dining Rating'].value_counts()
# Out:
# Dining Rating
# 0.0    5351
# 3.6     584
# 3.5     553
# 3.7     525
# 3.4     500
# 3.3     463
# 3.8     460
# 3.2     433
# 3.9     379
# 3.1     363
# 2.0     354
# 3.0     302
# 4.0     288
# 2.9     257
# 4.1     221
# 2.8     192
# 4.2     142
# 2.7     138
# 4.3     105
# 2.6      99
# 2.5      71
# 4.4      61
# 2.4      46
# 4.5      36
# 2.3      32
# 2.2      20
# 4.6      17
# 4.7      12
# 2.1      10
# 4.9       7
# 4.8       4
# 1.9       3
# 1.7       2
# 0.3       1
# 1.0       1
# Name: count, dtype: int64

# %%
raw_df['Delivery Rating'].value_counts()
# Out:
# Delivery Rating
# 0.0    5851
# 3.9    1383
# 3.8     701
# 4.0     570
# 3.7     559
# 4.1     468
# 3.6     465
# 4.2     401
# 3.5     314
# 4.3     277
# 3.4     259
# 3.3     189
# 4.4     128
# 3.2      93
# 3.1      79
# 3.0      63
# 4.5      55
# 2.9      39
# 2.8      26
# 4.6      24
# 2.7      19
# 2.6      17
# 2.5       9
# 0.3       8
# 2.4       7
# 2.3       5
# 2.2       5
# 2.0       5
# 1.8       5
# 4.7       4
# 2.1       2
# 1.6       1
# 1.5       1
# Name: count, dtype: int64

# %%
useless_data = (raw_df['Dining Rating'] == 0.0) & (raw_df['Delivery Rating'] == 0.0)
raw_df[useless_data]
# Out:
#                              Name of Restaurant         Location  \
# 1603                           Erode Amman Mess    Thiruvanmiyur
# 2159   The Ultimate Brownie And Chocolate Place   Sholinganallur
# 2419                     Amudha Aunty's kitchen   Sholinganallur
# 2537                                 TN 03 CAFE     Tiruvottiyur
# 2542                                Maggi Point         Tambaram
# ...                                         ...              ...
# 12027                           CK's Sandwiches            Porur
# 12028                           CK's Sandwiches         Kolathur
# 12029                           CK's Sandwiches  Anna Nagar East
# 12030                           CK's Sandwiches        Ramapuram
# 12031                           CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine      Top Dishes  \
# 1603   'Chettinad', ' South Indian', ' Kerala', ' Chi...         Invalid
# ...

# %%
raw_df = raw_df[~useless_data]

# %%
zomato_df = raw_df.copy()

# %%
zomato_df.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                          'Biryani'
# 1  'Biryani', ' North Indian', ' Mughlai', ' Dess...
# 2  'Biryani', ' North Indian', ' Chinese', ' Arab...
# 3  'Burger', ' Fast Food', ' Finger Food', ' Beve...
# 4  'Chinese', ' Biryani', ' North Indian', ' Chet...
#
#                                           Top Dishes  Price for 2  \
# 0  'Bread Halwa', ' Chicken 65', ' Mutton Biryani...          500
# 1  'Beef Biryani', ' Beef Fry', ' Paratha', ' Pay...         1000
# 2  'Brinjal Curry', ' Tandoori Chicken', ' Chicke...          500
# 3                                    'Zinger Burger'          500
# 4  'Mutton Biryani', ' Chicken Rice', ' Tomato Ri...          450
#
# ...

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# # Q1) How many restaurants are in Chennai?

# %%
top_locations = zomato_df['Location'].value_counts().head(20).index
filtered_df = zomato_df[zomato_df['Location'].isin(top_locations)]

fig = px.histogram(
    filtered_df,
    x='Location',
    color='Location',
    title='Top 20 Locations with Most Restaurants in Chennai',
    labels={'Location': 'Location'}
)
fig.show()

# %% [markdown]
# # Q2) Which are the Top 10 highest rated Dining Biriyani Restaurant in Chennai?

# %%
Biriyani_df = zomato_df[zomato_df['Cuisine'].str.contains('Biryani')]
Biriyani_df.sort_values(by='Dining Rating',ascending=False).head(10)
# Out:
#          Name of Restaurant         Location  \
# 116                  AlMaza  Anna Nagar East
# 199    Arabian Kebab Center      Kodambakkam
# 8757  Yaa Mohaideen Biryani       Pallavaram
# 154               Nair Mess       Triplicane
# 9037              Palmshore       Medavakkam
# 1        Sukkubhai Biriyani          Alandur
# 47                Palmshore           Egmore
# 283         Shiraz Art Cafe      Neelangarai
# 9038              Palmshore        Ramapuram
# 96            Urban Spatula  Anna Nagar West
#
#                                                 Cuisine  \
# 116   'Arabian', ' Mughlai', ' North Indian', ' Biry...
# 199                'Biryani', ' North Indian', ' Kebab'
# 8757                    'Biryani', ' Chinese', ' Tamil'
# 154                          'South Indian', ' Biryani'
# 9037  'North Indian', ' Chinese', ' Arabian', ' BBQ'...
# 1     'Biryani', ' North Indian', ' Mughlai', ' Dess...
# 47    'North Indian', ' Chinese', ' Arabian', ' BBQ'...
# ...

# %% [markdown]
# # Q3) Which places have the highest rated Delivery restaurant in Chennai?

# %%
highest_rated_df = zomato_df[zomato_df['Delivery Rating'] >= 4.5]
highest_rated_df
# Out:
#                        Name of Restaurant         Location  \
# 62     Amadora Gourmet Ice Cream & Sorbet     Nungambakkam
# 78                  Shri Rajasthani Dhaba  Anna Nagar West
# 92              Fruit Shop On Greams Road  Thousand Lights
# 163      Momo Sa-Khang by Kailash Kitchen      Choolaimedu
# 164                          La Chocolate           Egmore
# ...                                   ...              ...
# 11043                         Kulfi Treat         T. Nagar
# 11179                       Chennai Kulfi         Kolathur
# 11377            NIC - Natural Ice Creams         Mylapore
# 11379            NIC - Natural Ice Creams            Porur
# 11767                         Green Crush         Alwarpet
#
#                                                  Cuisine  \
# 62                              'Desserts', ' Ice Cream'
# 78                         'Rajasthani', ' North Indian'
# 92     'Beverages', ' Fast Food', ' Healthy Food', ' ...
# ...

# %%
fig = px.histogram(highest_rated_df, x='Name of Restaurant', color='Location',
title= 'No. of Best Restaurant by Places').update_xaxes(categoryorder="total descending")
fig.show()

# %% [markdown]
# # Q4) What is the Avg Price for 2 of highest rated restaurant in Chennai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['Location', 'Name of Restaurant'])['Price for 2'].mean().reset_index()
highest_rated_price_df.head()
# Out:
#      Location         Name of Restaurant  Price for 2
# 0  Adambakkam              Arabian Plate        300.0
# 1  Adambakkam                      ibaco        200.0
# 2       Adyar             Domino's Pizza        400.0
# 3       Adyar  Old Madras Baking Company        250.0
# 4    Alwarpet                Green Crush        200.0

# %%
fig = px.scatter(highest_rated_price_df, x="Location", y="Price for 2", color="Name of Restaurant", symbol="Name of Restaurant",
title=' Avg Price for 2 of High rated restaurant').update_traces(marker_size=10)
fig.show()

# %% [markdown]
# # Q5) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_df = zomato_df[zomato_df['Cuisine'].str.contains('Chinese')]
chinese_df
# Out:
#              Name of Restaurant                      Location  \
# 2          SS Hyderabad Biryani                   Kodambakkam
# 4                 Tasty Kitchen                      Perambur
# 5                    Dine N Fun                    Medavakkam
# 8             Savoury Sea Shell               Anna Nagar East
# 9      Sangeetha Veg Restaurant                      T. Nagar
# ...                         ...                           ...
# 11883              Hotel Rahman                  Chengalpattu
# 11886              Hotel Rahman                    Medavakkam
# 11887              Hotel Rahman  Old Mahabalipuram Road (OMR)
# 11959         The Shangai Story                    Madipakkam
# 11960         The Shangai Story                       Egatoor
#
#                                                  Cuisine  \
# 2      'Biryani', ' North Indian', ' Chinese', ' Arab...
# 4      'Chinese', ' Biryani', ' North Indian', ' Chet...
# ...

# %%
chinese_rest_df = chinese_df.groupby(by='Location').agg({
    'Name of Restaurant': 'count',
    'Price for 2': 'mean'
}).rename(columns={'Name of Restaurant': 'COUNT OF RESTAURANTS'})

chinese_rest_df = chinese_rest_df.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)
chinese_rest_df.head()
# Out:
#            COUNT OF RESTAURANTS  Price for 2
# Location
# Porur                        92   445.108696
# Ambattur                     82   395.731707
# T. Nagar                     78   507.051282
# Velachery                    78   533.333333
# Perambur                     76   434.210526

# %%
chinese_rest_df = chinese_rest_df.reset_index()

# %%
fig = px.bar(chinese_rest_df, x='Location', y='COUNT OF RESTAURANTS', color='Price for 2', title= 'No. of Chinese Restaurant by Places')
fig.show()

# %% [markdown]
# # Q6) Is there a relation between Location and Price for 2?

# %%
region_price_df = zomato_df.groupby(['Location'])['Price for 2'].mean().reset_index()
region_price_df
# Out:
#                                               Location  Price for 2
# 0     InterContinental Chennai Mahabalipuram Resort...  1500.000000
# 1                                        Abhiramapuram   230.000000
# 2                          Abu Sarovar Portico, Egmore  1000.000000
# 3                                           Adambakkam   306.790123
# 4                                                Adyar   476.562500
# ..                                                 ...          ...
# 259                              Vivira Mall, Navallur   500.000000
# 260                                       Washermenpet   340.909091
# 261             WelcomHotel, RK Salai (Cathedral Road)  2075.000000
# 262                                      West Mambalam   273.673469
# 263                     Zone by The Park, Pallikaranai  1633.333333
#
# [264 rows x 2 columns]
